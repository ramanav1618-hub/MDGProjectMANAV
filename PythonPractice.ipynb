# %%
import pandas as pd

# %%
df1=pd.read_excel("world_population_excel_workbook.xlsx", sheet_name="Sheet1") #read_csv() doesnt necessarily mean that the file has to be .csv. it can be .txt and others too
pd.set_option('display.max.rows',150) #modifies global behaviour for all dataframes 
pd.set_option('display.min.rows',100)
df1

#Header is just what the columns are called. 
#If we say that the dataframe we imported has header=None (no header) then it automatically gives 0,1,2... indexing
#If not, it assumes it has headers and it will make the first row of data the header.
#We can also specify the names of the header we want. we say header=None, Names=[name1, name2, ...]
#Depending on how data is separated in the csv file, we choose our sep. 
#Country,Region,Population,Area
#Afghanistan,ASIA,31056997,647500
#Albania,EASTERN EUROPE,3581655,28748
#Algeria,NORTHERN AFRICA,32930091,2381740
#This is an example of how a CSV may look like. It is an example where data entries are separated by comma.
#If the csv file (or any format like .txt, etc) is actually comma separated and we set sep to something else other than "," then it treats the entire line in the csv file as one 
#single data entry.
#Alternatively, we can use read_table
#The difference is that for read_csv(), the sep is set to "," by default
#for read_txt(), the sep is set to "/t" by default
#also pd.read_json exists too. json is semistructured data
#There is also read_excel()


#Display.max.rows: Only show the whole table if no. of rows are smaller than this number
#Display.min.rows: Only matters if maxrows is triggered. If the table is too long, show only these many rows.
# Out:
#      Rank CCA3                       Country              Capital
# 0      36  AFG                   Afghanistan                Kabul
# 1     138  ALB                       Albania               Tirana
# 2      34  DZA                       Algeria              Algiers
# 3     213  ASM                American Samoa            Pago Pago
# 4     203  AND                       Andorra     Andorra la Vella
# 5      42  AGO                        Angola               Luanda
# 6     224  AIA                      Anguilla           The Valley
# 7     201  ATG           Antigua and Barbuda       Saint Johnâ€™s
# 8      33  ARG                     Argentina         Buenos Aires
# 9     140  ARM                       Armenia              Yerevan
# 10    198  ABW                         Aruba           Oranjestad
# 11     55  AUS                     Australia             Canberra
# 12     99  AUT                       Austria               Vienna
# ...

# %%
#Filtering columns and rows in pandas
df2=pd.read_csv("world_population.csv")
df2
# Out:
#      Rank CCA3                       Country              Capital  \
# 0      36  AFG                   Afghanistan                Kabul
# 1     138  ALB                       Albania               Tirana
# 2      34  DZA                       Algeria              Algiers
# 3     213  ASM                American Samoa            Pago Pago
# 4     203  AND                       Andorra     Andorra la Vella
# 5      42  AGO                        Angola               Luanda
# 6     224  AIA                      Anguilla           The Valley
# 7     201  ATG           Antigua and Barbuda         Saint John’s
# 8      33  ARG                     Argentina         Buenos Aires
# 9     140  ARM                       Armenia              Yerevan
# 10    198  ABW                         Aruba           Oranjestad
# 11     55  AUS                     Australia             Canberra
# 12     99  AUT                       Austria               Vienna
# ...

# %%
specific_countries=["Bangladesh","Brazil"]
df2[df2["Country"].isin(specific_countries)]

df2[df2["2022 Population"]>df2["2020 Population"]]
# Out:
#      Rank CCA3                   Country              Capital      Continent  \
# 0      36  AFG               Afghanistan                Kabul           Asia
# 2      34  DZA                   Algeria              Algiers         Africa
# 4     203  AND                   Andorra     Andorra la Vella         Europe
# 5      42  AGO                    Angola               Luanda         Africa
# 6     224  AIA                  Anguilla           The Valley  North America
# 7     201  ATG       Antigua and Barbuda         Saint John’s  North America
# 8      33  ARG                 Argentina         Buenos Aires  South America
# 11     55  AUS                 Australia             Canberra        Oceania
# 12     99  AUT                   Austria               Vienna         Europe
# 14    176  BHS                   Bahamas               Nassau  North America
# 16      8  BGD                Bangladesh                Dhaka           Asia
# ...

# %%
df2=df2.set_index("Country")
df2.filter(like="stan", axis=0)
# Out:
#               Rank CCA3    Capital Continent  2022 Population  \
# Country
# Afghanistan     36  AFG      Kabul      Asia       41128771.0
# Kazakhstan      66  KAZ  Nursultan      Asia       19397998.0
# Kyrgyzstan     110  KGZ    Bishkek      Asia        6630623.0
# Pakistan         5  PAK  Islamabad      Asia      235824862.0
# Tajikistan      95  TJK   Dushanbe      Asia        9952787.0
# Turkmenistan   111  TKM   Ashgabat      Asia        6430770.0
# Uzbekistan      43  UZB   Tashkent      Asia       34627652.0
#
#               2020 Population  2015 Population  2010 Population  \
# Country
# Afghanistan        38972230.0       33753499.0       28189672.0
# Kazakhstan         18979243.0       17835909.0       16627837.0
# Kyrgyzstan          6424874.0        5914980.0        5483774.0
# Pakistan          227196741.0      210969298.0      194454498.0
# Tajikistan          9543207.0        8524063.0        7621779.0
# ...

# %%
df2.loc["United States"]
# Out:
# Rank                                          3
# CCA3                                        USA
# Capital                        Washington, D.C.
# Continent                         North America
# 2022 Population                     338289857.0
# 2020 Population                     335942003.0
# 2015 Population                     324607776.0
# 2010 Population                     311182845.0
# 2000 Population                     282398554.0
# 1990 Population                     248083732.0
# 1980 Population                     223140018.0
# 1970 Population                     200328340.0
# Area (km²)                            9372610.0
# Density (per km²)                       36.0935
# Growth Rate                              1.0038
# World Population Percentage                4.24
# Name: United States, dtype: object

# %%
df2.iloc[3]
# Out:
# Rank                                 213
# CCA3                                 ASM
# Capital                        Pago Pago
# Continent                        Oceania
# 2022 Population                  44273.0
# 2020 Population                  46189.0
# 2015 Population                  51368.0
# 2010 Population                  54849.0
# 2000 Population                  58230.0
# 1990 Population                  47818.0
# 1980 Population                  32886.0
# 1970 Population                  27075.0
# Area (km²)                         199.0
# Density (per km²)               222.4774
# Growth Rate                       0.9831
# World Population Percentage          0.0
# Name: American Samoa, dtype: object

# %%
df2.sort_values(by=["Rank"], ascending=[True])
# Out:
#                                   Rank CCA3           Capital      Continent  \
# Country
# China                                1  CHN           Beijing           Asia
# India                                2  IND         New Delhi           Asia
# United States                        3  USA  Washington, D.C.  North America
# Indonesia                            4  IDN           Jakarta           Asia
# Pakistan                             5  PAK         Islamabad           Asia
# Nigeria                              6  NGA             Abuja         Africa
# Brazil                               7  BRA          Brasilia  South America
# Bangladesh                           8  BGD             Dhaka           Asia
# Russia                               9  RUS            Moscow         Europe
# Mexico                              10  MEX       Mexico City  North America
# Japan                               11  JPN             Tokyo           Asia
# ...
